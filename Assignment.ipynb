# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounika766181/Mounika766181/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Pyspark

# %%
# !pip install pyspark

# %% [markdown]
# Creates SparkSession

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder \
.appName("CSV Assignment") \
.getOrCreate()

# %% [markdown]
# Uploade files from local

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-5d136cbc-1c34-48cf-95f7-af979f60b313" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d136cbc-1c34-48cf-95f7-af979f60b313">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# To read csv file

# %%
df=spark.read.csv("indexProcessed.csv", header=True,inferSchema=True)

# %% [markdown]
# Action

# %%
df.show(5)
# Out:
# +-----+----------+-----------+-----------+-----------+-----------+-----------+------+------------------+
# |Index|      Date|       Open|       High|        Low|      Close|  Adj Close|Volume|          CloseUSD|
# +-----+----------+-----------+-----------+-----------+-----------+-----------+------+------------------+
# |  HSI|1986-12-31|2568.300049|2568.300049|2568.300049|2568.300049|2568.300049|   0.0|      333.87900637|
# |  HSI|1987-01-02|2540.100098|2540.100098|2540.100098|2540.100098|2540.100098|   0.0|      330.21301274|
# |  HSI|1987-01-05|2552.399902|2552.399902|2552.399902|2552.399902|2552.399902|   0.0|      331.81198726|
# |  HSI|1987-01-06|2583.899902|2583.899902|2583.899902|2583.899902|2583.899902|   0.0|335.90698726000005|
# |  HSI|1987-01-07|2607.100098|2607.100098|2607.100098|2607.100098|2607.100098|   0.0|      338.92301274|
# +-----+----------+-----------+-----------+-----------+-----------+-----------+------+------------------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Index: string (nullable = true)
#  |-- Date: date (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Adj Close: double (nullable = true)
#  |-- Volume: double (nullable = true)
#  |-- CloseUSD: double (nullable = true)

# %%
df.count()
# Out:
# 104224

# %% [markdown]
# Transformation

# %%
df1=df.select("Date","close")

# %%
df2=df.dropDuplicates()
df2.show()
# Out:
# +-----+----------+-----------+-----------+-----------+-----------+-----------+------+------------------+
# |Index|      Date|       Open|       High|        Low|      Close|  Adj Close|Volume|          CloseUSD|
# +-----+----------+-----------+-----------+-----------+-----------+-----------+------+------------------+
# |  HSI|1987-08-20|     3408.0|     3408.0|     3408.0|     3408.0|     3408.0|   0.0|            443.04|
# |  HSI|1987-09-17|3571.399902|3571.399902|3571.399902|3571.399902|3571.399902|   0.0|464.28198726000005|
# |  HSI|1988-04-19|2593.899902|2593.899902|2593.899902|2593.899902|2593.899902|   0.0|      337.20698726|
# |  HSI|1988-04-22|2591.399902|2591.399902|2591.399902|2591.399902|2591.399902|   0.0|      336.88198726|
# |  HSI|1988-06-07|     2587.0|     2587.0|     2587.0|     2587.0|     2587.0|   0.0|            336.31|
# |  HSI|1988-11-01|2615.399902|2615.399902|2615.399902|2615.399902|2615.399902|   0.0|      340.00198726|
# ...

# %%
json_data="""
{"EmpID":101,"Name":"Jose","Department":"IT","Salary":60000}
{"EmpID":102,"Name":"Kenny","Department":"CSE","Salary":70000}
{"EmpID":103,"Name":"Sara","Department":"IT","Salary":60000}
{"EmpID":104,"Name":"Julie","Department":"Supply","Salary":80000}
{"EmpID":105,"Name":"Henry","Department":"IT","Salary":80000}
{"EmpID":106,"Name":"Jermy","Department":"CSE","Salary":70000}
{"EmpID":107,"Name":"Jade","Department":"Supply","Salary":60000}
{"EmpID":108,"Name":"Boyd","Department":"CSE","Salary":80000}
{"EmpID":109,"Name":"Tabitha","Department":"Supply","Salary":90000}
{"EmpID":110,"Name":"Victor","Department":"IT","Salary":100000}
"""
with open("employees.json", "w") as f:
   f.write(json_data)

# %%
df=spark.read.json("employees.json")

# %%
df.show()
# Out:
# +----------+-----+-------+------+
# |Department|EmpID|   Name|Salary|
# +----------+-----+-------+------+
# |        IT|  101|   Jose| 60000|
# |       CSE|  102|  Kenny| 70000|
# |        IT|  103|   Sara| 60000|
# |    Supply|  104|  Julie| 80000|
# |        IT|  105|  Henry| 80000|
# |       CSE|  106|  Jermy| 70000|
# |    Supply|  107|   Jade| 60000|
# |       CSE|  108|   Boyd| 80000|
# |    Supply|  109|Tabitha| 90000|
# |        IT|  110| Victor|100000|
# +----------+-----+-------+------+

# %%
from pyspark.sql.functions import max, avg

# %% [markdown]
# Transformation

# %%
max_salary=df.select(max("Salary"))

# %% [markdown]
# Action

# %%
max_salary.show()
# Out:
# +-----------+
# |max(Salary)|
# +-----------+
# |     100000|
# +-----------+

# %%
avg_salary=df.select(avg("salary").alias("AvgrageSalary"))

# %%
avg_salary.show()
# Out:
# +-------------+
# |AvgrageSalary|
# +-------------+
# |      75000.0|
# +-------------+

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3d6e99e5-1e8a-4c94-a175-cb68a72c301f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d6e99e5-1e8a-4c94-a175-cb68a72c301f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=spark.read.parquet("iris.parquet")

# %%
df.count()
# Out:
# 150

# %%
df.printSchema()
# Out:
# root
#  |-- sepal.length: double (nullable = true)
#  |-- sepal.width: double (nullable = true)
#  |-- petal.length: double (nullable = true)
#  |-- petal.width: double (nullable = true)
#  |-- variety: string (nullable = true)

# %%
df.show(5)
# Out:
# +------------+-----------+------------+-----------+-------+
# |sepal.length|sepal.width|petal.length|petal.width|variety|
# +------------+-----------+------------+-----------+-------+
# |         5.1|        3.5|         1.4|        0.2| Setosa|
# |         4.9|        3.0|         1.4|        0.2| Setosa|
# |         4.7|        3.2|         1.3|        0.2| Setosa|
# |         4.6|        3.1|         1.5|        0.2| Setosa|
# |         5.0|        3.6|         1.4|        0.2| Setosa|
# +------------+-----------+------------+-----------+-------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col

# %%
df1=df.select("`sepal.length`", "variety")
df1.show()
# Out:
# +------------+-------+
# |sepal.length|variety|
# +------------+-------+
# |         5.1| Setosa|
# |         4.9| Setosa|
# |         4.7| Setosa|
# |         4.6| Setosa|
# |         5.0| Setosa|
# |         5.4| Setosa|
# |         4.6| Setosa|
# |         5.0| Setosa|
# |         4.4| Setosa|
# |         4.9| Setosa|
# |         5.4| Setosa|
# |         4.8| Setosa|
# |         4.8| Setosa|
# |         4.3| Setosa|
# |         5.8| Setosa|
# |         5.7| Setosa|
# |         5.4| Setosa|
# |         5.1| Setosa|
# |         5.7| Setosa|
# |         5.1| Setosa|
# +------------+-------+
# only showing top 20 rows
